# %%
import netCDF4 as nc
from pathlib import Path
import glob

#Array 
import xarray as xr
import numpy as np
import datetime as dt
import pandas as pd
import dask

#Visualize
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
import matplotlib.colors as colors
import cmcrameri.cm as cmc # batlow colourmap

#large data visualization
import datashader as ds
from datashader import transfer_functions as tf, reductions as rd

# Analyse
from scipy import signal
from scipy.interpolate import BSpline

#import tqdm
import seaborn as sns



import CL61_module
from CL61_module import module as mCL61

# %%
import importlib  # To reload files
importlib.reload(mCL61)
# Out:
# <module 'CL61_module.module' from 'c:\\Users\\gezas\\kDrive\\SIE-Project\\CL61\\CL61_module\\module.py'>

# %%
plt.style.use('bmh')

COLOR_MAP = 'cmc.batlow'

# %% [markdown]
# # Open dataset

# %%
februar_cl61 = mCL61.CL61Processor(folder_path='../CL61/Data', specific_filename='temp_20230204.nc')
june = mCL61.CL61Processor(folder_path='../CL61/Data', specific_filename='temp_1d_test.nc')

# %%
februar_cl61.mask_noise()
june.mask_noise()
# Out:
# kernel size [5, 5]
# kernel size [1, 3]
# kernel size [5, 5]
# kernel size [1, 3]

# %%
februar_cl61.visualize_data(plot_type='colormesh', varriable_names=['beta_att_clean', 'linear_depol_ratio_clean'])

# %%
june.visualize_data(plot_type='colormesh')

# %%
june.visualize_data(plot_type='colormesh', varriable_names=['beta_att_clean', 'linear_depol_ratio_clean'])

# %%
june.classify_data_kmean()
# Out:
# (4635540, 1)
# Scaler means: [-5.64626956]
#  and scales: [0.51826226]
# c:\Users\gezas\.conda\envs\atm\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\gezas\.conda\envs\atm\Lib\site-packages\xarray\core\dataset.py:1393, in Dataset._construct_dataarray(self, name)
#    1392 try:
# -> 1393     variable = self._variables[name]
#    1394 except KeyError:
#
# KeyError: 'classified'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\gezas\kDrive\SIE-Project\CL61\main.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gezas/kDrive/SIE-Project/CL61/main.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> june.classify_data_kmean()
#
# File c:\Users\gezas\kDrive\SIE-Project\CL61\CL61_module\module.py:139, in CL61Processor.classify_data_kmean(self, cluster_number, plot_result)
#     136 self.dataset['kmean_classified'] = xr.DataArray(data=classification_result_array.T, dims=['time', 'range'])
#     138 if plot_result:
# --> 139     visualization.plot_classifiction_result(dataset=self.dataset, classified_var_name = 'kmean_classified')
#     141 return
#
# File c:\Users\gezas\kDrive\SIE-Project\CL61\CL61_module\visualization.py:155, in plot_classifiction_result(dataset, classified_var_name, colormap)
#     152 original_cmap = plt.get_cmap(colormap)
#     154 # Define the number of discrete categories
# --> 155 num_categories = dataset['classified'].unique().size  # Adjust as needed
#     157 # Create a list of evenly spaced values to sample the colormap
#     158 color_values = np.linspace(0, 1, num_categories)
#
# File c:\Users\gezas\.conda\envs\atm\Lib\site-packages\xarray\core\dataset.py:1484, in Dataset.__getitem__(self, key)
#    1482     return self.isel(**key)
#    1483 if utils.hashable(key):
# -> 1484     return self._construct_dataarray(key)
#    1485 if utils.iterable_of_hashable(key):
#    1486     return self._copy_listed(key)
#
# File c:\Users\gezas\.conda\envs\atm\Lib\site-packages\xarray\core\dataset.py:1395, in Dataset._construct_dataarray(self, name)
#    1393     variable = self._variables[name]
#    1394 except KeyError:
# -> 1395     _, name, variable = _get_virtual_variable(self._variables, name, self.dims)
#    1397 needed_dims = set(variable.dims)
#    1399 coords: dict[Hashable, Variable] = {}
#
# File c:\Users\gezas\.conda\envs\atm\Lib\site-packages\xarray\core\dataset.py:196, in _get_virtual_variable(variables, key, dim_sizes)
#     194 split_key = key.split(".", 1)
#     195 if len(split_key) != 2:
# --> 196     raise KeyError(key)
#     198 ref_name, var_name = split_key
#     199 ref_var = variables[ref_name]
#
# KeyError: 'classified'

# %%
depolarization_threshold = {
    'liquid_droplets': [0,0.2],
    'smoke' : [0.02, 0.1],
    'dust' : [0.1, 0.2],
    'snow': [0.2, 0.4],
    'ice crystals': [0.35, 1],
    'graupel':[0.4, 1]
}
